# %%
import pickle
from pathlib import Path

# %%
import streamlit_authenticator as stauth

# %%
names = ["Joshita", "Vanshita"]
usernames = ["jgupta","vansh123"]
passwords = ["abc123", "def456"]

# %%
hashed_passwords =  stauth.Hasher(passwords).generate
hashed_passwords
# Out:
# <bound method Hasher.generate of <streamlit_authenticator.utilities.hasher.Hasher object at 0x000002234FB939D0>>

# %%
# Define the file path relative to the current working directory
file_path = Path.cwd().parent / "hashed_pw.pkl"
# file_path

# Open the file and save the hashed passwords
with file_path.open("wb") as file:
    pickle.dump(hashed_passwords, file)
file_path
# Out:
# WindowsPath('c:/Users/lenovo/OneDrive - IIAIAC.org/NSE/NSE_Case_Study/Projects/NSE_Daily_Performance_Data/hashed_pw.pkl')
